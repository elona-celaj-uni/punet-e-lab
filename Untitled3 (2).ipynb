# %% [markdown]
# #**tekst bold**
# Pune laboratori 1

# %% [markdown]
# Raport Laboratori – Elektronikë
#
# **Titulli i Eksperimentit:** Qarqet me Rezistenca
# **Lënda:** Hyrje në Elektronikë
# **Pedagogu:** Ervin Kafexhiu
# **Student(ët):** Elona Celaj
#
# **Grupi:** -
#
# **Data e zhvillimit:** (data)
#
# **Data e dorëzimit:** (data)#

# %% [markdown]
# ## Qellimi i eksperimentit
#
# Qëllimi i këtij eksperimenti është studimi i një qarku RC dhe analizimi i përgjigjes së tij në frekuencë.
# Verifikohet sjellja e filtrit të rendit të parë dhe përcaktohet frekuenca e prerjes.
# Gjithashtu analizohet marrëdhënia midis amplitudës së sinjalit hyrës dhe dalës.

# %% [markdown]
# ## Te dhenat

# %%
R1=10.22
R2=10.05
ratio_theoretical=R2/(R1+R2)
ratio_theoretical
# Out:
# 0.49580661075481003

# %%
Ud=0.260
Uh=0.531
ratio_exp =Ud/Uh
ratio_exp
# Out:
# 0.4896421845574388

# %% [markdown]
# ## Verehet qe jane shume afer ,kjo eshte perfekte per raportin , KUJDES; Uh/Ud =2.04 dhe Ud/Uh=0.49

# %% [markdown]
# error = abs(ratio_exp - ratio_theoretical) / ratio_theoretical * 100
# error

# %%
teorike = 0.496
eksperimentale = 0.49

gabimi = abs(eksperimentale - teorike) / teorike * 100
gabimi
# Out:
# 1.2096774193548396

# %% [markdown]
# ## Analiza e të Dhënave
#
# Raporti teorik i tensionit është:
#
# Ud/Uh = R2 / (R1 + R2) = 0.496
#
# Nga matjet eksperimentale:
#
# Ud/Uh = 0.260 / 0.531 = 0.49
#
# Vërehet që vlerat janë shumë të afërta.
#
# Gabimi relativ:
#
# 1.2%
#
# perputhje mes teoris e eksperimentit

# %% [markdown]
# Devijimi i vogël vjen nga:
# - tolerancat e rezistorëve
# - pasaktësia e matjes së tensionit
# - humbje të vogla në qark

# %% [markdown]
# ## Pjesa 2
# hasen 3 rezistenca
#
# Ndares tensioni me ngarkese R3;
#
# R1 dhe R2 formojne ndaresin
#
# R3 eshte ngarkese ne dalje paralele me R2

# %%
R2 = 96.7 * 1000   # kΩ → Ω
R3 = 98.4          # Ω

Req = (R2 * R3) / (R2 + R3)
Req
# Out:
# 98.299971900362

# %% [markdown]
# R3 << R2
# Req = R3

# %% [markdown]
# tani qarku behet ;
#
# R1 ne seri me Req

# %%
R1 = 85300
Req = 98

ratio_theoretical = Req / (R1 + Req)
ratio_theoretical
# Out:
# 0.0011475678587320546

# %% [markdown]
# ## nga matjet e mia;

# %%
Ud = 0.263
Uh = 11.32

ratio_exp = Ud / Uh
ratio_exp
# Out:
# 0.02323321554770318

# %% [markdown]
# ## Dicka nuk shkon, diference shume e madhe
# mendoj se dicka e till vjen si pasoje e;
#
# R3 nuk është lidhur si mendoj
#
# (ndoshta nuk është paralel me R2)
#
# Gabim në njësi
#
# R3 = 98.4 Ω (shumë i vogël)
#
# R1, R2 janë kΩ
#
# kjo e shkatërron ndarësin (dalja bie shumë)

# %% [markdown]
#  ## Me shum mundesi gabimi kyc qendron tek R3
#
#  nqs R3 eshte 98.4 k ohm ateher ka logjik;

# %%
R2 = 96700
R3 = 98400

Req = (R2 * R3) / (R2 + R3)
Req
# Out:
# 48771.29677088672

# %%
R1 = 85300
Req = 48000

ratio = Req / (R1 + Req)
ratio
# Out:
# 0.3600900225056264

# %% [markdown]
# ## shum afer realitetit

# %% [markdown]
#  ##pjesa 3
#
#  AnaLizoj ndikimin e R3 tek dalja, per cdo R3 te ndryshem duhet te llogaris Ud/Uh

# %%
Ud1 = 1.561
Uh = 11.32

ratio1 = Ud1 / Uh
ratio1
# Out:
# 0.1378975265017668

# %%
Ud2 = 1.889

ratio2 = Ud2 / Uh
ratio2
# Out:
# 0.16687279151943463

# %% [markdown]
# ## Analiza e të Dhënave
#
# U vu re se ndryshimi i rezistencës së ngarkesës R3 ndikon ndjeshëm në tensionin e daljes.
#
# Për R3 = 82 kΩ:
# Ud/Uh ≈ 0.138
#
# Për R3 = 56 kΩ:
# Ud/Uh ≈ 0.167
#
# Kur R3 zvogëlohet, tensioni në dalje ndryshon për shkak të efektit të ngarkesës në qark

# %%
import matplotlib.pyplot as plt

R3 = [82, 56]
ratio = [0.138, 0.167]

plt.plot(R3, ratio, marker='o')
plt.xlabel("R3 (kΩ)")
plt.ylabel("Ud/Uh")
plt.title("Ndikimi i R3 në dalje")
plt.grid()
plt.show()

# %% [markdown]
# ## Të Dhënat e Matura
#
# | R3 (kΩ) | Ud (V) | Uh (V) | Ud/Uh |
# |--------|-------|-------|------|
# | 82     | 1.561 | 11.32 | 0.138 |
# | 56     | 1.889 | 11.32 | 0.167 |

# %% [markdown]
# Ud/Uh=R2/(R1+R2)
#
# dhe anasjelltas Uh/Ud=(R1+R2)/R2
#
# ku Uh=11.32 V
#
# R1=20.64 kohm
#
# R2=20.83 kohm

# %% [markdown]
# Llogaritja teorike e tensionit ne dalje;
# Ud=5.68 V

# %% [markdown]
# Pra vlera teorike 5.68 V
# dhe ajo  eksperimentale 5.57 V

# %%
## Gabimi relativ
U_teorik = 5.68
U_eksperimental = 5.57

gabimi_relativ = abs(U_eksperimental - U_teorik) / U_teorik * 100

print("Gabimi relativ =", gabimi_relativ, "%")
# Out:
# Gabimi relativ = 1.9366197183098492 %

# %% [markdown]
# Cfare ndodh kur ndryshohet R3,
#
# duhet llogaritur raporti Ud/Uh ;
#
# kur dihet qe kam ;

# %%
import pandas as pd

# Krijimi i të dhënave
data = {
    'R3 (kΩ)': [7.59, 51.3, 365.6],
    'Ud (V)': [2.169, 4.73, 5.57],
    'Uh (V)': [11.32, 11.32, 11.32]
}

# Krijimi i DataFrame
df = pd.DataFrame(data)

# Shfaqja e tabelës
df
# Out:
#    R3 (kΩ)  Ud (V)  Uh (V)
# 0     7.59   2.169   11.32
# 1    51.30   4.730   11.32
# 2   365.60   5.570   11.32

# %%
import pandas as pd
import numpy as np

Uh = 11.32

R3 = [7.59, 51.3, 365.6]
Ud = [2.169, 4.73, 5.57]

raporti = np.array(Ud)/Uh

data = pd.DataFrame({
    "R3 (kOhm)": R3,
    "Ud (V)": Ud,
    "Uh (V)": Uh,
    "Ud/Uh": raporti
})

print(data)
# Out:
#    R3 (kOhm)  Ud (V)  Uh (V)     Ud/Uh
# 0       7.59   2.169   11.32  0.191608
# 1      51.30   4.730   11.32  0.417845
# 2     365.60   5.570   11.32  0.492049

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))

plt.plot(R3, raporti, marker='o')

plt.xlabel("R3 (kΩ)")
plt.ylabel("Ud/Uh")
plt.title("Ndikimi i R3 në raportin e tensionit")
plt.grid(True)

plt.show()

# %% [markdown]
# DISKUTIM
#
# Sjellja e qarkut
#
# Kur rezistenca R3 rritet, tensioni në dalje Ud rritet gradualisht dhe afrohet me vlerën teorike të ndarësit të tensionit.
# Kur R3 është shumë e vogël krahasuar me  R2 qarku ngarkohet më shumë dhe tensioni në dalje bie ndjeshëm.
# Kur R3 bëhet shumë e madhe, efekti i ngarkesës zvogëlohet dhe qarku sillet më afër modelit ideal teorik.

# %% [markdown]
# ### Burimet kryesore të gabimit
#
# *   **Tolerancat e rezistorëve**
#     Rezistorët realë kanë tolerancë (zakonisht ±1% ose ±5%), prandaj vlerat reale ndryshojnë nga ato nominale.
# *   **Pasiguritë e matjes**
#     Multimetri ka kufizim në saktësi dhe rezolucion.
# *   **Kufizimet e instrumenteve**
#     Rezistenca e brendshme e instrumenteve mund të ndikojë në matje.
# *   **Efektet parazitare**
#     Lidhjet, kabllot dhe kontaktet krijojnë rezistenca shtesë të vogla.

# %% [markdown]
# ### Përfundim
# Nga eksperimenti u verifikua funksionimi i ndarësit të tensionit.
#
# * **Vlera teorike:** 5.68V
# * **Vlera eksperimentale:** 5.57V
# * **Devijimi relativ:** 1.94%
#
# Rezultatet eksperimentale janë shumë pranë atyre teorike, duke treguar se modeli teorik përshkruan mirë sjelljen e qarkut. Devijimet e vogla vijnë nga tolerancat e komponentëve dhe kufizimet e instrumenteve matëse.
